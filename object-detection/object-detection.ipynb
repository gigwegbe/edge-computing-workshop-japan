# %%
# Load detection functions 
from detector_nms import detect_objects, load_image
from PIL import Image
# Out:
# WARNING:absl:Importing a function (__inference_pruned_6248) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.

# %%
# !ls sample-directory2/
# Out:
# blue-bear.6cbjdlbp.jpg  brown-bear.6cbj601n.jpg pink-bear.6cbjf4u7.jpg
# blue-bear.6cbjdlhq.jpg  brown-bear.6cbj675p.jpg pink-bear.6cbjf5o2.jpg
# blue-bear.6cbjds5a.jpg  brown-bear.6cbj67eq.jpg

# %% [markdown]
# ## First Sample

# %%
image = load_image("./sample-directory2/blue-bear.6cbjdlbp.jpg")
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
output = detect_objects("./sample-directory2/blue-bear.6cbjdlbp.jpg")
print("Result saved at:", output)
# Out:
# Saved annotated image to ./detected/blue-bear.6cbjdlbp_detections.jpg
# Result saved at: ./detected/blue-bear.6cbjdlbp_detections.jpg

# %%
image = load_image(output)
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Second Sample

# %%
image = load_image("./sample-directory2/brown-bear.6cbj675p.jpg")
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
output = detect_objects("./sample-directory2/brown-bear.6cbj675p.jpg")
print("Result saved at:", output)
# Out:
# Saved annotated image to ./detected/brown-bear.6cbj675p_detections.jpg
# Result saved at: ./detected/brown-bear.6cbj675p_detections.jpg

# %%
image = load_image(output)
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Third Sample

# %%
image = load_image("./sample-directory2/pink-bear.6cbjf4u7.jpg")
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
output = detect_objects("./sample-directory2/pink-bear.6cbjf5o2.jpg")
print("Result saved at:", output)
# Out:
# Saved annotated image to ./detected/pink-bear.6cbjf5o2_detections.jpg
# Result saved at: ./detected/pink-bear.6cbjf5o2_detections.jpg

# %%
image = load_image(output)
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Fourth Sample

# %%
# TODO - Pick an image and repeat the process above !!

# %%
image = load_image("./sample-directory/IMG_4826.jpg")
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
output = detect_objects("./sample-directory/IMG_4826.jpg")
print("Result saved at:", output)
# Out:
# Saved annotated image to ./detected/IMG_4826_detections.jpg
# Result saved at: ./detected/IMG_4826_detections.jpg

# %%
image = load_image(output)
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
